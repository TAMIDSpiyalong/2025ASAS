# %% [markdown]
# <a href="https://colab.research.google.com/github/TAMIDSpiyalong/2025ASAS/blob/main/computer_vision_for_feed_grading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem

# %% [markdown]
# This lecture explores the potential of computer vision in precision livestock farming, focusing on its applications in automated feeding grading tasks. The example image dataset is collected from a Calan Gate Feeding System on a research facility at Texas A&M University, Department of Animal Science, College Station, TX.

# %% [markdown]
# # Objectives

# %% [markdown]
# * Understanding the mathmatics behind the neural network
# * Create a simple neural network to perform image classification
# * Create a convolutional neural network (CNN) for the same problem
# * Use transfer learning to build a ResNet for the same problem
# * Understand the prediction and evaluate the computer vision performance

# %%
import torch
import numpy as np
import torchvision
import matplotlib.pyplot as plt
import time
import seaborn as sn
import pandas as pd

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # Data

# %% [markdown]
# To monitor the feeding behavior of the beef cattles, we installed a high-definition video capture system, which consisted of three Reolink PoE cameras (Model D400) positioned above the feeding bunks to cover all bunks, with each camera capturing two bunks. The cameras were configured to record at a resolution of Full HD (1920x1080 pixels) with a frame rate of 30 frames per second (FPS).
#
# Consecutive frames are extracted from livestock monitoring videos and cropped to focus only on feeding bunks. The pixel coordinates of the feed bunks in the cameras are hand-picked, which will vary from camera to camera but remain the same for fixed cameras. The time of each frame is derived using its FPS rate based on the beginning time of the videos.

# %%
import gdown
import os

if "mixture.zip" not in os.listdir():

  gdown.download('https://drive.google.com/uc?export=download&id=1nhqowKssfpHaGFhK6ilIuC0zYEBoeZ_4')
  ! unzip -q "mixture.zip"
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1nhqowKssfpHaGFhK6ilIuC0zYEBoeZ_4
# To: /content/mixture.zip
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 103MB/s]

# %% [markdown]
# Based on the following literature, we define the six different bunk scores from S00 to S4: S00 (no feed), S05 (scattered feed), S10 (thin layer), S20 (25-50%), S30 (> 50%), and S40 (untouched) (Lundy et al., 2015). Open the images in the file explore you can see the examples.
#
# Lundy, E., Loy, D., Dahlke, G., 2015. Iowa Beef Center Feed Bunk Management.  https://store.extension.iastate.edu/product/4593

# %% [markdown]
# ## Load Images

# %% [markdown]
# torchvision.datasets.ImageFolder is a PyTorch class that simplifies loading image datasets by organizing them into a directory structure where each subdirectory represents a class or category of images. In practice, it is more complicated but doable with care.

# %%
images = torchvision.datasets.ImageFolder('mixture/')

# %%
images[4][0]
# Out:
# <PIL.Image.Image image mode=RGB size=500x450>

# %%
print(np.array(images[4][0]).shape)
# Out:
# (450, 500, 3)

# %% [markdown]
# ## Image Transformation

# %% [markdown]
# PyTorch transformations are crucial for preparing datasets before training machine learning models. They ensure standardization and normalization, which scale data points uniformly to prevent features with large ranges from dominating the training process. Transformations also enable data augmentation through techniques like rotation, flipping, and cropping, helping prevent overfitting and improve model generalization. Additionally, transformations ensure consistency by resizing images to uniform dimensions, which is necessary for batch processing in neural networks.

# %%
import torchvision.transforms as transforms

# this is the mean and standard deviation for imagenet dataset
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])

transform = transforms.Compose([
        # transforms.ColorJitter(brightness=(0.5, 1.5)),  # Adjust brightness
        transforms.Resize((128,128)),
        # transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        # transforms.Normalize(mean, std),
        transforms.Grayscale()
    ])

# %%
images = torchvision.datasets.ImageFolder('mixture/',transform)

# %%
class_names = images.classes
print(images.classes)
print(len(images))
print(len(images[99]))

image_tensor = images[100][0]

print(image_tensor.shape)

image_label = images[100][1]

print(image_label)

print(images[0][0]*255,images[0][1])

image_to_display = image_tensor.permute(1, 2, 0).cpu().numpy()

# Display the image
plt.title('GT: '+class_names[int(image_label)])
plt.imshow(image_to_display, cmap='gray')
plt.show()
# Out:
# ['S00', 'S05', 'S10', 'S20', 'S30', 'S40']
# 183
# 2
# torch.Size([1, 128, 128])
# 2
# tensor([[[ 88.0082,  50.0120,  51.0119,  ..., 111.9871, 139.8810, 167.3468],
#          [ 46.0124,  51.0119,  53.0117,  ..., 108.8133, 138.8811, 158.3477],
#          [ 49.8980,  51.0119,  51.0119,  ..., 109.8841, 141.8808, 157.3478],
#          ...,
#          [ 21.1244,  19.5267,  13.3532,  ..., 105.7308,  58.1854,  72.0530],
#          [ 14.2391,  14.2283,  10.1686,  ...,  89.1885,  69.1134,  92.6380],
#          [ 14.8261,  11.0545,   8.6356,  ...,  89.6445,  70.7003,  88.4705]]]) 0

# %%
image_to_display.shape
# Out:
# (128, 128, 1)

# %% [markdown]
# ## Data Split for Training, Validation, and Testing

# %%
data_size = len(images.imgs)
train_size = int(data_size*0.7)
val_size = (data_size-train_size)//2
test_size = data_size-train_size-val_size
train_set, val_set, test_set = torch.utils.data.random_split(images, (train_size,val_size,test_size))
train_size,test_size,val_size
# Out:
# (128, 28, 27)

# %% [markdown]
# ## Dataloader

# %% [markdown]
# PyTorch's DataLoader is crucial for efficiently handling large datasets and optimizing the data loading process in deep learning workflows. It allows you to split your dataset into batches, providing an iterable interface to access these batches sequentially, which is essential for training neural networks.

# %%
from torch.utils.data import DataLoader

batch_size=32

train_dataloader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=1)
test_dataloader = DataLoader(test_set, batch_size=batch_size, shuffle=True, num_workers=1)
val_dataloader = DataLoader(val_set, batch_size=batch_size, shuffle=True, num_workers=1)

# %% [markdown]
# ### visualize the input examples

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    # inp = std * inp + mean # correct the nornalization
    # inp = np.clip(inp, 0, 1)
    plt.imshow(inp)

# Get a batch of training data
inputs, classes = next(iter(train_dataloader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)
plt.figure(figsize=(10,5))
imshow(out, title='Input Examples')
print([class_names[i] for i in classes])
# Out:
# ['S00', 'S05', 'S05', 'S30', 'S30', 'S20', 'S05', 'S40', 'S05', 'S30', 'S10', 'S05', 'S10', 'S05', 'S10', 'S10', 'S30', 'S30', 'S05', 'S30', 'S30', 'S05', 'S10', 'S20', 'S30', 'S10', 'S05', 'S10', 'S30', 'S30', 'S05', 'S10']

# %%
test_set[0][0].shape
# Out:
# torch.Size([1, 128, 128])

# %% [markdown]
# ### Result Visualization

# %% [markdown]
# # Simple Neural Network

# %%
import torch.nn as nn

class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.fc1 = nn.Linear(16384, 1000)
        self.fc2 = nn.Linear(1000, 100)
        self.fc3 = nn.Linear(100, 6)    # Output layer is the same dimension as the classes

    def forward(self, x):
        x = x.view(-1, 16384)  # Flatten the input
        x = torch.relu(self.fc1(x))  # Activation function for hidden layer
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

model = SimpleModel().to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.0001, momentum=0.9)

# %% [markdown]
# ## Training

# %%
since = time.time()

best_acc = 0.0
num_epochs=50

for epoch in range(num_epochs):
    print('-' * 10)

    model.train()  # Set model to training mode
    train_running_loss = 0.0
    train_running_corrects = 0

    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # backward + optimize only if in training phase
        loss.backward()
        optimizer.step()

        # statistics
        train_running_loss += loss.item() * inputs.size(0)
        train_running_corrects += torch.sum(preds == labels.data)

    train_epoch_loss = train_running_loss / len(train_set)
    train_accuracy = train_running_corrects.double() / len(train_set)
    print(f"Epoch {epoch + 1}/{num_epochs}, Training Loss: {train_epoch_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%")

    # Each epoch has a validation phase

    model.eval()   # Set model to evaluate mode
    val_running_loss = 0.0
    val_running_corrects = 0

    # Iterate over data.
    for inputs, labels in val_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # statistics
        val_running_loss += loss.item() * inputs.size(0)
        val_running_corrects += torch.sum(preds == labels.data)

    val_epoch_loss = val_running_loss / len(val_set)
    val_accuracy = val_running_corrects.double() / len(val_set)
    print(f"Epoch {epoch + 1}/{num_epochs}, Validation Loss: {val_epoch_loss:.4f}, validation Accuracy: {val_accuracy:.2f}%")

        # deep copy the model
    if  val_accuracy > best_acc:
        best_acc = val_accuracy
        best_model = model.state_dict()

time_elapsed = time.time() - since
print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
print('Best val Acc: {:4f}'.format(best_acc))
# Out:
# ----------
# Epoch 1/50, Training Loss: 1.7779, Training Accuracy: 0.11%
# Epoch 1/50, Validation Loss: 1.7851, validation Accuracy: 0.11%
# ----------
# Epoch 2/50, Training Loss: 1.7758, Training Accuracy: 0.16%
# Epoch 2/50, Validation Loss: 1.7831, validation Accuracy: 0.11%
# ----------
# Epoch 3/50, Training Loss: 1.7730, Training Accuracy: 0.20%
# Epoch 3/50, Validation Loss: 1.7806, validation Accuracy: 0.15%
# ----------
# Epoch 4/50, Training Loss: 1.7690, Training Accuracy: 0.20%
# Epoch 4/50, Validation Loss: 1.7779, validation Accuracy: 0.15%
# ----------
# Epoch 5/50, Training Loss: 1.7648, Training Accuracy: 0.23%
# Epoch 5/50, Validation Loss: 1.7749, validation Accuracy: 0.22%
# ----------
# Epoch 6/50, Training Loss: 1.7602, Training Accuracy: 0.27%
# Epoch 6/50, Validation Loss: 1.7718, validation Accuracy: 0.26%
# ----------
# Epoch 7/50, Training Loss: 1.7556, Training Accuracy: 0.31%
# Epoch 7/50, Validation Loss: 1.7685, validation Accuracy: 0.26%
# ----------
# Epoch 8/50, Training Loss: 1.7511, Training Accuracy: 0.32%
# Epoch 8/50, Validation Loss: 1.7650, validation Accuracy: 0.26%
# ----------
# Epoch 9/50, Training Loss: 1.7465, Training Accuracy: 0.32%
# Epoch 9/50, Validation Loss: 1.7615, validation Accuracy: 0.26%
# ----------
# Epoch 10/50, Training Loss: 1.7411, Training Accuracy: 0.32%
# Epoch 10/50, Validation Loss: 1.7581, validation Accuracy: 0.26%
# ----------
# Epoch 11/50, Training Loss: 1.7360, Training Accuracy: 0.32%
# Epoch 11/50, Validation Loss: 1.7546, validation Accuracy: 0.26%
# ----------
# Epoch 12/50, Training Loss: 1.7311, Training Accuracy: 0.32%
# Epoch 12/50, Validation Loss: 1.7511, validation Accuracy: 0.26%
# ----------
# Epoch 13/50, Training Loss: 1.7268, Training Accuracy: 0.32%
# Epoch 13/50, Validation Loss: 1.7476, validation Accuracy: 0.26%
# ----------
# Epoch 14/50, Training Loss: 1.7212, Training Accuracy: 0.32%
# Epoch 14/50, Validation Loss: 1.7444, validation Accuracy: 0.26%
# ----------
# Epoch 15/50, Training Loss: 1.7167, Training Accuracy: 0.32%
# Epoch 15/50, Validation Loss: 1.7412, validation Accuracy: 0.26%
# ----------
# Epoch 16/50, Training Loss: 1.7117, Training Accuracy: 0.32%
# Epoch 16/50, Validation Loss: 1.7380, validation Accuracy: 0.26%
# ----------
# Epoch 17/50, Training Loss: 1.7073, Training Accuracy: 0.32%
# Epoch 17/50, Validation Loss: 1.7349, validation Accuracy: 0.26%
# ----------
# Epoch 18/50, Training Loss: 1.7032, Training Accuracy: 0.32%
# Epoch 18/50, Validation Loss: 1.7318, validation Accuracy: 0.26%
# ----------
# Epoch 19/50, Training Loss: 1.6986, Training Accuracy: 0.32%
# Epoch 19/50, Validation Loss: 1.7288, validation Accuracy: 0.26%
# ----------
# Epoch 20/50, Training Loss: 1.6940, Training Accuracy: 0.32%
# Epoch 20/50, Validation Loss: 1.7260, validation Accuracy: 0.26%
# ----------
# Epoch 21/50, Training Loss: 1.6898, Training Accuracy: 0.32%
# Epoch 21/50, Validation Loss: 1.7231, validation Accuracy: 0.26%
# ----------
# Epoch 22/50, Training Loss: 1.6853, Training Accuracy: 0.32%
# Epoch 22/50, Validation Loss: 1.7204, validation Accuracy: 0.26%
# ----------
# Epoch 23/50, Training Loss: 1.6815, Training Accuracy: 0.32%
# Epoch 23/50, Validation Loss: 1.7176, validation Accuracy: 0.26%
# ----------
# Epoch 24/50, Training Loss: 1.6772, Training Accuracy: 0.32%
# Epoch 24/50, Validation Loss: 1.7150, validation Accuracy: 0.26%
# ----------
# Epoch 25/50, Training Loss: 1.6731, Training Accuracy: 0.32%
# Epoch 25/50, Validation Loss: 1.7125, validation Accuracy: 0.26%
# ----------
# Epoch 26/50, Training Loss: 1.6696, Training Accuracy: 0.32%
# Epoch 26/50, Validation Loss: 1.7098, validation Accuracy: 0.26%
# ----------
# Epoch 27/50, Training Loss: 1.6656, Training Accuracy: 0.32%
# Epoch 27/50, Validation Loss: 1.7073, validation Accuracy: 0.26%
# ----------
# Epoch 28/50, Training Loss: 1.6622, Training Accuracy: 0.32%
# Epoch 28/50, Validation Loss: 1.7051, validation Accuracy: 0.26%
# ----------
# Epoch 29/50, Training Loss: 1.6581, Training Accuracy: 0.32%
# Epoch 29/50, Validation Loss: 1.7030, validation Accuracy: 0.26%
# ----------
# Epoch 30/50, Training Loss: 1.6556, Training Accuracy: 0.32%
# Epoch 30/50, Validation Loss: 1.7009, validation Accuracy: 0.26%
# ----------
# Epoch 31/50, Training Loss: 1.6516, Training Accuracy: 0.32%
# Epoch 31/50, Validation Loss: 1.6989, validation Accuracy: 0.26%
# ----------
# Epoch 32/50, Training Loss: 1.6484, Training Accuracy: 0.32%
# Epoch 32/50, Validation Loss: 1.6968, validation Accuracy: 0.26%
# ----------
# Epoch 33/50, Training Loss: 1.6455, Training Accuracy: 0.32%
# Epoch 33/50, Validation Loss: 1.6952, validation Accuracy: 0.26%
# ----------
# Epoch 34/50, Training Loss: 1.6427, Training Accuracy: 0.32%
# Epoch 34/50, Validation Loss: 1.6933, validation Accuracy: 0.26%
# ----------
# Epoch 35/50, Training Loss: 1.6398, Training Accuracy: 0.32%
# Epoch 35/50, Validation Loss: 1.6917, validation Accuracy: 0.26%
# ----------
# Epoch 36/50, Training Loss: 1.6371, Training Accuracy: 0.32%
# Epoch 36/50, Validation Loss: 1.6900, validation Accuracy: 0.26%
# ----------
# Epoch 37/50, Training Loss: 1.6341, Training Accuracy: 0.32%
# Epoch 37/50, Validation Loss: 1.6882, validation Accuracy: 0.26%
# ----------
# Epoch 38/50, Training Loss: 1.6317, Training Accuracy: 0.32%
# Epoch 38/50, Validation Loss: 1.6866, validation Accuracy: 0.26%
# ----------
# Epoch 39/50, Training Loss: 1.6292, Training Accuracy: 0.32%
# Epoch 39/50, Validation Loss: 1.6850, validation Accuracy: 0.26%
# ----------
# Epoch 40/50, Training Loss: 1.6267, Training Accuracy: 0.32%
# Epoch 40/50, Validation Loss: 1.6836, validation Accuracy: 0.26%
# ----------
# Epoch 41/50, Training Loss: 1.6245, Training Accuracy: 0.32%
# Epoch 41/50, Validation Loss: 1.6822, validation Accuracy: 0.26%
# ----------
# Epoch 42/50, Training Loss: 1.6223, Training Accuracy: 0.32%
# Epoch 42/50, Validation Loss: 1.6807, validation Accuracy: 0.26%
# ----------
# Epoch 43/50, Training Loss: 1.6200, Training Accuracy: 0.32%
# Epoch 43/50, Validation Loss: 1.6793, validation Accuracy: 0.26%
# ----------
# Epoch 44/50, Training Loss: 1.6179, Training Accuracy: 0.32%
# Epoch 44/50, Validation Loss: 1.6782, validation Accuracy: 0.26%
# ----------
# Epoch 45/50, Training Loss: 1.6160, Training Accuracy: 0.32%
# Epoch 45/50, Validation Loss: 1.6768, validation Accuracy: 0.26%
# ----------
# Epoch 46/50, Training Loss: 1.6137, Training Accuracy: 0.32%
# Epoch 46/50, Validation Loss: 1.6756, validation Accuracy: 0.26%
# ----------
# Epoch 47/50, Training Loss: 1.6118, Training Accuracy: 0.32%
# Epoch 47/50, Validation Loss: 1.6744, validation Accuracy: 0.26%
# ----------
# Epoch 48/50, Training Loss: 1.6100, Training Accuracy: 0.32%
# Epoch 48/50, Validation Loss: 1.6731, validation Accuracy: 0.26%
# ----------
# Epoch 49/50, Training Loss: 1.6083, Training Accuracy: 0.32%
# Epoch 49/50, Validation Loss: 1.6720, validation Accuracy: 0.26%
# ----------
# Epoch 50/50, Training Loss: 1.6062, Training Accuracy: 0.32%
# Epoch 50/50, Validation Loss: 1.6709, validation Accuracy: 0.26%
# Training complete in 0m 46s
# Best val Acc: 0.259259

# %% [markdown]
# # Train a Model with Pretrained Weights

# %% [markdown]
# We need to modigy the original pre-defined model becuase our input channel is only one. Also the output classes of the original resnet is 1000 whereas we only want 6 classes.

# %%
model = torchvision.models.resnet18(pretrained=True)

num_ftrs = model.fc.in_features
# The last layer should have len(class_names neruons)
model.fc = nn.Linear(num_ftrs, len(class_names))

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3,bias=False)

model = model.to(device)
# Out:
# /usr/local/lib/python3.13/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 151MB/s]

# %%
since = time.time()

best_acc = 0.0
num_epochs=50

for epoch in range(num_epochs):
    print('-' * 10)

    model.train()  # Set model to training mode
    train_running_loss = 0.0
    train_running_corrects = 0

    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # backward + optimize only if in training phase
        loss.backward()
        optimizer.step()

        # statistics
        train_running_loss += loss.item() * inputs.size(0)
        train_running_corrects += torch.sum(preds == labels.data)

    train_epoch_loss = train_running_loss / len(train_set)
    train_accuracy = train_running_corrects.double() / len(train_set)
    print(f"Epoch {epoch + 1}/{num_epochs}, Training Loss: {train_epoch_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%")

    # Each epoch has a validation phase

    model.eval()   # Set model to evaluate mode
    val_running_loss = 0.0
    val_running_corrects = 0

    # Iterate over data.
    for inputs, labels in val_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # statistics
        val_running_loss += loss.item() * inputs.size(0)
        val_running_corrects += torch.sum(preds == labels.data)

    val_epoch_loss = val_running_loss / len(val_set)
    val_accuracy = val_running_corrects.double() / len(val_set)
    print(f"Epoch {epoch + 1}/{num_epochs}, Validation Loss: {val_epoch_loss:.4f}, validation Accuracy: {val_accuracy:.2f}%")

        # deep copy the model
    if  val_accuracy > best_acc:
        best_acc = val_accuracy
        best_model = model.state_dict()

time_elapsed = time.time() - since
print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
print('Best val Acc: {:4f}'.format(best_acc))
# Out:
# ----------
# Epoch 1/50, Training Loss: 1.7986, Training Accuracy: 0.23%
# Epoch 1/50, Validation Loss: 1.9609, validation Accuracy: 0.11%
# ----------
# Epoch 2/50, Training Loss: 0.5509, Training Accuracy: 0.93%
# Epoch 2/50, Validation Loss: 2.0389, validation Accuracy: 0.07%
# ----------
# Epoch 3/50, Training Loss: 0.2191, Training Accuracy: 0.99%
# Epoch 3/50, Validation Loss: 1.9865, validation Accuracy: 0.07%
# ----------
# Epoch 4/50, Training Loss: 0.1062, Training Accuracy: 1.00%
# Epoch 4/50, Validation Loss: 1.9928, validation Accuracy: 0.07%
# ----------
# Epoch 5/50, Training Loss: 0.0580, Training Accuracy: 1.00%
# Epoch 5/50, Validation Loss: 2.0217, validation Accuracy: 0.19%
# ----------
# Epoch 6/50, Training Loss: 0.0394, Training Accuracy: 1.00%
# Epoch 6/50, Validation Loss: 2.1276, validation Accuracy: 0.19%
# ----------
# Epoch 7/50, Training Loss: 0.0188, Training Accuracy: 1.00%
# Epoch 7/50, Validation Loss: 2.1829, validation Accuracy: 0.15%
# ----------
# Epoch 8/50, Training Loss: 0.0142, Training Accuracy: 1.00%
# Epoch 8/50, Validation Loss: 2.1452, validation Accuracy: 0.19%
# ----------
# Epoch 9/50, Training Loss: 0.0174, Training Accuracy: 1.00%
# Epoch 9/50, Validation Loss: 2.0620, validation Accuracy: 0.19%
# ----------
# Epoch 10/50, Training Loss: 0.0085, Training Accuracy: 1.00%
# Epoch 10/50, Validation Loss: 1.9565, validation Accuracy: 0.26%
# ----------
# Epoch 11/50, Training Loss: 0.0067, Training Accuracy: 1.00%
# Epoch 11/50, Validation Loss: 1.8256, validation Accuracy: 0.30%
# ----------
# Epoch 12/50, Training Loss: 0.0076, Training Accuracy: 1.00%
# Epoch 12/50, Validation Loss: 1.6739, validation Accuracy: 0.30%
# ----------
# Epoch 13/50, Training Loss: 0.0062, Training Accuracy: 1.00%
# Epoch 13/50, Validation Loss: 1.5650, validation Accuracy: 0.37%
# ----------
# Epoch 14/50, Training Loss: 0.0051, Training Accuracy: 1.00%
# Epoch 14/50, Validation Loss: 1.4178, validation Accuracy: 0.37%
# ----------
# Epoch 15/50, Training Loss: 0.0042, Training Accuracy: 1.00%
# Epoch 15/50, Validation Loss: 1.1858, validation Accuracy: 0.52%
# ----------
# Epoch 16/50, Training Loss: 0.0040, Training Accuracy: 1.00%
# Epoch 16/50, Validation Loss: 0.9540, validation Accuracy: 0.63%
# ----------
# Epoch 17/50, Training Loss: 0.0041, Training Accuracy: 1.00%
# Epoch 17/50, Validation Loss: 0.7815, validation Accuracy: 0.70%
# ----------
# Epoch 18/50, Training Loss: 0.0042, Training Accuracy: 1.00%
# Epoch 18/50, Validation Loss: 0.6707, validation Accuracy: 0.85%
# ----------
# Epoch 19/50, Training Loss: 0.0035, Training Accuracy: 1.00%
# Epoch 19/50, Validation Loss: 0.6002, validation Accuracy: 0.89%
# ----------
# Epoch 20/50, Training Loss: 0.0040, Training Accuracy: 1.00%
# Epoch 20/50, Validation Loss: 0.5813, validation Accuracy: 0.89%
# ----------
# Epoch 21/50, Training Loss: 0.0037, Training Accuracy: 1.00%
# Epoch 21/50, Validation Loss: 0.5679, validation Accuracy: 0.89%
# ----------
# Epoch 22/50, Training Loss: 0.0047, Training Accuracy: 1.00%
# Epoch 22/50, Validation Loss: 0.5630, validation Accuracy: 0.89%
# ----------
# Epoch 23/50, Training Loss: 0.0050, Training Accuracy: 1.00%
# Epoch 23/50, Validation Loss: 0.5670, validation Accuracy: 0.89%
# ----------
# Epoch 24/50, Training Loss: 0.0030, Training Accuracy: 1.00%
# Epoch 24/50, Validation Loss: 0.5699, validation Accuracy: 0.89%
# ----------
# Epoch 25/50, Training Loss: 0.0033, Training Accuracy: 1.00%
# Epoch 25/50, Validation Loss: 0.5696, validation Accuracy: 0.89%
# ----------
# Epoch 26/50, Training Loss: 0.0026, Training Accuracy: 1.00%
# Epoch 26/50, Validation Loss: 0.5709, validation Accuracy: 0.89%
# ----------
# Epoch 27/50, Training Loss: 0.0064, Training Accuracy: 1.00%
# Epoch 27/50, Validation Loss: 0.5651, validation Accuracy: 0.89%
# ----------
# Epoch 28/50, Training Loss: 0.0028, Training Accuracy: 1.00%
# Epoch 28/50, Validation Loss: 0.5703, validation Accuracy: 0.89%
# ----------
# Epoch 29/50, Training Loss: 0.0032, Training Accuracy: 1.00%
# Epoch 29/50, Validation Loss: 0.5732, validation Accuracy: 0.89%
# ----------
# Epoch 30/50, Training Loss: 0.0026, Training Accuracy: 1.00%
# Epoch 30/50, Validation Loss: 0.5792, validation Accuracy: 0.89%
# ----------
# Epoch 31/50, Training Loss: 0.0025, Training Accuracy: 1.00%
# Epoch 31/50, Validation Loss: 0.5763, validation Accuracy: 0.89%
# ----------
# Epoch 32/50, Training Loss: 0.0027, Training Accuracy: 1.00%
# Epoch 32/50, Validation Loss: 0.5809, validation Accuracy: 0.89%
# ----------
# Epoch 33/50, Training Loss: 0.0015, Training Accuracy: 1.00%
# Epoch 33/50, Validation Loss: 0.5823, validation Accuracy: 0.89%
# ----------
# Epoch 34/50, Training Loss: 0.0026, Training Accuracy: 1.00%
# Epoch 34/50, Validation Loss: 0.5855, validation Accuracy: 0.89%
# ----------
# Epoch 35/50, Training Loss: 0.0026, Training Accuracy: 1.00%
# Epoch 35/50, Validation Loss: 0.5915, validation Accuracy: 0.89%
# ----------
# Epoch 36/50, Training Loss: 0.0025, Training Accuracy: 1.00%
# Epoch 36/50, Validation Loss: 0.5996, validation Accuracy: 0.89%
# ----------
# Epoch 37/50, Training Loss: 0.0027, Training Accuracy: 1.00%
# Epoch 37/50, Validation Loss: 0.6034, validation Accuracy: 0.89%
# ----------
# Epoch 38/50, Training Loss: 0.0016, Training Accuracy: 1.00%
# Epoch 38/50, Validation Loss: 0.6063, validation Accuracy: 0.89%
# ----------
# Epoch 39/50, Training Loss: 0.0015, Training Accuracy: 1.00%
# Epoch 39/50, Validation Loss: 0.6032, validation Accuracy: 0.89%
# ----------
# Epoch 40/50, Training Loss: 0.0016, Training Accuracy: 1.00%
# Epoch 40/50, Validation Loss: 0.6077, validation Accuracy: 0.89%
# ----------
# Epoch 41/50, Training Loss: 0.0026, Training Accuracy: 1.00%
# Epoch 41/50, Validation Loss: 0.6086, validation Accuracy: 0.89%
# ----------
# Epoch 42/50, Training Loss: 0.0013, Training Accuracy: 1.00%
# Epoch 42/50, Validation Loss: 0.6071, validation Accuracy: 0.89%
# ----------
# Epoch 43/50, Training Loss: 0.0017, Training Accuracy: 1.00%
# Epoch 43/50, Validation Loss: 0.6045, validation Accuracy: 0.89%
# ----------
# Epoch 44/50, Training Loss: 0.0013, Training Accuracy: 1.00%
# Epoch 44/50, Validation Loss: 0.6024, validation Accuracy: 0.89%
# ----------
# Epoch 45/50, Training Loss: 0.0013, Training Accuracy: 1.00%
# Epoch 45/50, Validation Loss: 0.5993, validation Accuracy: 0.89%
# ----------
# Epoch 46/50, Training Loss: 0.0024, Training Accuracy: 1.00%
# Epoch 46/50, Validation Loss: 0.6004, validation Accuracy: 0.89%
# ----------
# Epoch 47/50, Training Loss: 0.0012, Training Accuracy: 1.00%
# Epoch 47/50, Validation Loss: 0.5981, validation Accuracy: 0.89%
# ----------
# Epoch 48/50, Training Loss: 0.0014, Training Accuracy: 1.00%
# Epoch 48/50, Validation Loss: 0.5944, validation Accuracy: 0.89%
# ----------
# Epoch 49/50, Training Loss: 0.0012, Training Accuracy: 1.00%
# Epoch 49/50, Validation Loss: 0.5951, validation Accuracy: 0.89%
# ----------
# Epoch 50/50, Training Loss: 0.0015, Training Accuracy: 1.00%
# Epoch 50/50, Validation Loss: 0.6001, validation Accuracy: 0.89%
# Training complete in 0m 48s
# Best val Acc: 0.888889

# %% [markdown]
# ### Saving the Best Model and Load

# %%
torch.save(best_model, 'best_model.pth')

# %% [markdown]
# This is testing on the testing portion, which is from the same mixture.

# %%
model = torchvision.models.resnet18(pretrained=True)

num_ftrs = model.fc.in_features
# The last layer should have len(class_names neruons)
model.fc = nn.Linear(num_ftrs, len(class_names))

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3,bias=False)

model.load_state_dict(torch.load('best_model.pth'))

model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=6, bias=True)
# )

# %%
model.eval()
too_many_figures=0

sm = torch.nn.Softmax()
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_dataloader):
        inputs = inputs.to(device)
        l=labels
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        confidence = np.amax(np.array(sm(outputs.cpu())),1)

        for j in range(inputs.size()[0]):
            fig = plt.figure()
            ax = plt.subplot()
            ax.set_xlabel('Groun Truth: {}'.format(class_names[l[j]]))
            ax.set_ylabel('Prediction: {}'.format(class_names[preds[j]]))
            ax.set_title('Confidence {:.2f}'.format(confidence[j]))

            inp = inputs.cpu().data[j].numpy().transpose((1, 2, 0))

            # inp = std * inp + mean
            # inp = np.clip(inp, 0, 1)
            ax.imshow(inp, cmap='gray')
            too_many_figures+=1
            if too_many_figures>10:
                break
        if too_many_figures>10:
            break
# Out:
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py:1779: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# /tmp/ipykernel_6273/474806721.py:13: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   confidence = np.amax(np.array(sm(outputs.cpu())),1)

# %% [markdown]
# # Test on unseen data

# %% [markdown]
# Now we make the test dataloader to load the random selected pictures and get the confusion matrix. We can see the model works for the random selected pictures. The key for next steps is to get diverse training dataset to cover many different conditions. This also can be done by data augmentation.

# %%
if "RANDOM_PICTURES_TO_VERIFY.zip" not in os.listdir():

    gdown.download('https://drive.google.com/uc?export=download&id=1zMIA-i0_M6mVPCnMshJQxgVXz8u_m40r')
    ! unzip -q 'RANDOM_PICTURES_TO_VERIFY.zip'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1zMIA-i0_M6mVPCnMshJQxgVXz8u_m40r
# From (redirected): https://drive.google.com/uc?export=download&id=1zMIA-i0_M6mVPCnMshJQxgVXz8u_m40r&confirm=t&uuid=270bddde-65ed-4722-88ab-c411e12a3295
# To: /content/RANDOM_PICTURES_TO_VERIFY.zip
# 100%|██████████| 569M/569M [00:04<00:00, 128MB/s]

# %%
test_set = torchvision.datasets.ImageFolder('RANDOM_PICTURES_TO_VERIFY/',transform)

# %%
test_dataloader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=1)

# %% [markdown]
# # Confusion Matrix Result Analysis

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
model.to(device)
with torch.no_grad():

    for i, (inputs, classes) in enumerate(test_dataloader):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1

print(confusion_matrix)
# Out:
# tensor([[9.0600e+02, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 3.1890e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [1.0000e+00, 9.2000e+01, 1.1880e+03, 0.0000e+00, 5.2000e+01, 5.0000e+00],
#         [0.0000e+00, 0.0000e+00, 4.7000e+01, 6.0700e+02, 2.8000e+01, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 4.7000e+01, 6.1000e+01, 1.1150e+03, 3.0000e+01],
#         [0.0000e+00, 8.0000e+00, 0.0000e+00, 0.0000e+00, 8.2000e+01, 4.4700e+02]])

# %%
df_cm = pd.DataFrame(confusion_matrix.numpy().astype('int'), index = [i for i in class_names],
                  columns = [i for i in class_names])

test_acc=np.trace(confusion_matrix.numpy().astype('int'))/np.sum(np.sum(df_cm))

plt.figure(figsize = (len(class_names),len(class_names)))
plt.title('Confusing Matrix with Testing Accuracy: {:0.2f}%'.format(test_acc*100))

sn.heatmap(df_cm, annot=True,fmt='g',cmap="YlGnBu")
plt.xlabel('Predicted Label')
plt.ylabel('Ground Truth')
plt.savefig('Confusing Matrix.pdf',dpi=300)
# Out:
# /usr/local/lib/python3.13/dist-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Initialize for confusion matrix and metrics calculation
# Assuming `images.classes`, `model`, `device`, `test_dataloader` are defined in earlier cells.
nb_classes = len(images.classes)
confusion_matrix_tensor = torch.zeros(nb_classes, nb_classes)
all_labels = []
all_preds = []

model.eval() # Set model to evaluation mode
with torch.no_grad():
    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

        # Populate confusion matrix
        for t, p in zip(labels.view(-1), preds.view(-1)):
            confusion_matrix_tensor[t.long(), p.long()] += 1

        # Collect all labels and predictions for macro/weighted averages
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())

# Calculate macro-averaged metrics
macro_precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
macro_recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)
macro_f1 = f1_score(all_labels, all_preds, average='macro', zero_division=0)

# Calculate weighted-averaged metrics
weighted_precision = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
weighted_recall = recall_score(all_labels, all_preds, average='weighted', zero_division=0)
weighted_f1 = f1_score(all_labels, all_preds, average='weighted', zero_division=0)

# Now, use the confusion_matrix_tensor and calculated macro/weighted metrics to build the combined DataFrame
cm_np = confusion_matrix_tensor.numpy().astype('int')
recall_class_wise = np.diag(cm_np) / (np.sum(cm_np, axis=1) + 0.000000001)
precision_class_wise = np.diag(cm_np) / (np.sum(cm_np, axis=0) + 0.000000001)
f1_per_class = 2 * (precision_class_wise * recall_class_wise) / (precision_class_wise + recall_class_wise)
f1_per_class = np.nan_to_num(f1_per_class, nan=0.0) # Handle potential NaN for classes with no predictions/labels

data_class_wise = {'Metric': [f'Precision ({cls})' for cls in images.classes] +
                             [f'Recall ({cls})' for cls in images.classes] +
                             [f'F1-score ({cls})' for cls in images.classes],
                   'Value': np.concatenate([precision_class_wise, recall_class_wise, f1_per_class])}
df_combined = pd.DataFrame(data_class_wise)

df_combined = pd.concat([df_combined, pd.DataFrame([
    {'Metric': 'Macro Precision', 'Value': macro_precision},
    {'Metric': 'Macro Recall', 'Value': macro_recall},
    {'Metric': 'Macro F1-score', 'Value': macro_f1},
    {'Metric': 'Weighted Precision', 'Value': weighted_precision},
    {'Metric': 'Weighted Recall', 'Value': weighted_recall},
    {'Metric': 'Weighted F1-score', 'Value': weighted_f1}
])], ignore_index=True)

df_combined['Value'] = df_combined['Value'].apply(lambda x: '{:.2%}'.format(x))

display(df_combined.style.set_properties(**{'text-align': 'left'}))
# Out:
# <style type="text/css">
# #T_26786_row0_col0, #T_26786_row0_col1, #T_26786_row1_col0, #T_26786_row1_col1, #T_26786_row2_col0, #T_26786_row2_col1, #T_26786_row3_col0, #T_26786_row3_col1, #T_26786_row4_col0, #T_26786_row4_col1, #T_26786_row5_col0, #T_26786_row5_col1, #T_26786_row6_col0, #T_26786_row6_col1, #T_26786_row7_col0, #T_26786_row7_col1, #T_26786_row8_col0, #T_26786_row8_col1, #T_26786_row9_col0, #T_26786_row9_col1, #T_26786_row10_col0, #T_26786_row10_col1, #T_26786_row11_col0, #T_26786_row11_col1, #T_26786_row12_col0, #T_26786_row12_col1, #T_26786_row13_col0, #T_26786_row13_col1, #T_26786_row14_col0, #T_26786_row14_col1, #T_26786_row15_col0, #T_26786_row15_col1, #T_26786_row16_col0, #T_26786_row16_col1, #T_26786_row17_col0, #T_26786_row17_col1, #T_26786_row18_col0, #T_26786_row18_col1, #T_26786_row19_col0, #T_26786_row19_col1, #T_26786_row20_col0, #T_26786_row20_col1, #T_26786_row21_col0, #T_26786_row21_col1, #T_26786_row22_col0, #T_26786_row22_col1, #T_26786_row23_col0, #T_26786_row23_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_26786" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26786_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_26786_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26786_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26786_row0_col0" class="data row0 col0" >Precision (S00)</td>
#       <td id="T_26786_row0_col1" class="data row0 col1" >99.89%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26786_row1_col0" class="data row1 col0" >Precision (S05)</td>
#       <td id="T_26786_row1_col1" class="data row1 col1" >96.96%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26786_row2_col0" class="data row2 col0" >Precision (S10)</td>
#       <td id="T_26786_row2_col1" class="data row2 col1" >92.67%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26786_row3_col0" class="data row3 col0" >Precision (S20)</td>
#       <td id="T_26786_row3_col1" class="data row3 col1" >90.87%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_26786_row4_col0" class="data row4 col0" >Precision (S30)</td>
#       <td id="T_26786_row4_col1" class="data row4 col1" >87.31%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_26786_row5_col0" class="data row5 col0" >Precision (S40)</td>
#       <td id="T_26786_row5_col1" class="data row5 col1" >92.74%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_26786_row6_col0" class="data row6 col0" >Recall (S00)</td>
#       <td id="T_26786_row6_col1" class="data row6 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_26786_row7_col0" class="data row7 col0" >Recall (S05)</td>
#       <td id="T_26786_row7_col1" class="data row7 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_26786_row8_col0" class="data row8 col0" >Recall (S10)</td>
#       <td id="T_26786_row8_col1" class="data row8 col1" >88.79%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_26786_row9_col0" class="data row9 col0" >Recall (S20)</td>
#       <td id="T_26786_row9_col1" class="data row9 col1" >89.00%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_26786_row10_col0" class="data row10 col0" >Recall (S30)</td>
#       <td id="T_26786_row10_col1" class="data row10 col1" >88.99%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_26786_row11_col0" class="data row11 col0" >Recall (S40)</td>
#       <td id="T_26786_row11_col1" class="data row11 col1" >83.24%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_26786_row12_col0" class="data row12 col0" >F1-score (S00)</td>
#       <td id="T_26786_row12_col1" class="data row12 col1" >99.94%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_26786_row13_col0" class="data row13 col0" >F1-score (S05)</td>
#       <td id="T_26786_row13_col1" class="data row13 col1" >98.46%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_26786_row14_col0" class="data row14 col0" >F1-score (S10)</td>
#       <td id="T_26786_row14_col1" class="data row14 col1" >90.69%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_26786_row15_col0" class="data row15 col0" >F1-score (S20)</td>
#       <td id="T_26786_row15_col1" class="data row15 col1" >89.93%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_26786_row16_col0" class="data row16 col0" >F1-score (S30)</td>
#       <td id="T_26786_row16_col1" class="data row16 col1" >88.14%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_26786_row17_col0" class="data row17 col0" >F1-score (S40)</td>
#       <td id="T_26786_row17_col1" class="data row17 col1" >87.73%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_26786_row18_col0" class="data row18 col0" >Macro Precision</td>
#       <td id="T_26786_row18_col1" class="data row18 col1" >93.41%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_26786_row19_col0" class="data row19 col0" >Macro Recall</td>
#       <td id="T_26786_row19_col1" class="data row19 col1" >91.67%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_26786_row20_col0" class="data row20 col0" >Macro F1-score</td>
#       <td id="T_26786_row20_col1" class="data row20 col1" >92.48%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_26786_row21_col0" class="data row21 col0" >Weighted Precision</td>
#       <td id="T_26786_row21_col1" class="data row21 col1" >94.23%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_26786_row22_col0" class="data row22 col0" >Weighted Recall</td>
#       <td id="T_26786_row22_col1" class="data row22 col1" >94.27%</td>
#     </tr>
#     <tr>
#       <th id="T_26786_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_26786_row23_col0" class="data row23 col0" >Weighted F1-score</td>
#       <td id="T_26786_row23_col1" class="data row23 col1" >94.21%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comprehensive Evaluation Metrics
#
# This table summarizes the model's performance, including class-wise, macro-averaged, and weighted-averaged metrics. The macro-averaged metrics treat all classes equally, while weighted-averaged metrics account for class imbalance by considering the number of true instances for each class.

# %%
df

# %%
styled_df = df.style.format({'Precision': '{:.2%}', 'Recall': '{:.2%}','F1': '{:.2%}'})
styled_df
