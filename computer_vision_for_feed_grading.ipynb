# %% [markdown]
# <a href="https://colab.research.google.com/github/TAMIDSpiyalong/2025ASAS/blob/main/computer_vision_for_feed_grading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem

# %% [markdown]
# This lecture explores the potential of computer vision in precision livestock farming, focusing on its applications in automated feeding grading tasks. The example image dataset is collected from a Calan Gate Feeding System on a research facility at Texas A&M University, Department of Animal Science, College Station, TX.

# %% [markdown]
# # Objectives

# %% [markdown]
# * Understanding the mathmatics behind the neural network
# * Create a simple neural network to perform image classification
# * Create a convolutional neural network (CNN) for the same problem
# * Use transfer learning to build a ResNet for the same problem
# * Understand the prediction and evaluate the computer vision performance

# %%
import torch
import numpy as np
import torchvision
import matplotlib.pyplot as plt
import time
import seaborn as sn
import pandas as pd

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # Data

# %% [markdown]
# To monitor the feeding behavior of the beef cattles, we installed a high-definition video capture system, which consisted of three Reolink PoE cameras (Model D400) positioned above the feeding bunks to cover all bunks, with each camera capturing two bunks. The cameras were configured to record at a resolution of Full HD (1920x1080 pixels) with a frame rate of 30 frames per second (FPS).
#
# Consecutive frames are extracted from livestock monitoring videos and cropped to focus only on feeding bunks. The pixel coordinates of the feed bunks in the cameras are hand-picked, which will vary from camera to camera but remain the same for fixed cameras. The time of each frame is derived using its FPS rate based on the beginning time of the videos.

# %%
import gdown
import os

if "mixture.zip" not in os.listdir():

  gdown.download('https://drive.google.com/uc?export=download&id=1nhqowKssfpHaGFhK6ilIuC0zYEBoeZ_4')
  ! unzip -q "mixture.zip"

# %% [markdown]
# Based on the following literature, we define the six different bunk scores from S00 to S4: S00 (no feed), S05 (scattered feed), S10 (thin layer), S20 (25-50%), S30 (> 50%), and S40 (untouched) (Lundy et al., 2015). Open the images in the file explore you can see the examples.
#
# Lundy, E., Loy, D., Dahlke, G., 2015. Iowa Beef Center Feed Bunk Management.  https://store.extension.iastate.edu/product/4593

# %% [markdown]
# ## Load Images

# %% [markdown]
# torchvision.datasets.ImageFolder is a PyTorch class that simplifies loading image datasets by organizing them into a directory structure where each subdirectory represents a class or category of images. In practice, it is more complicated but doable with care.

# %%
images = torchvision.datasets.ImageFolder('mixture/')

# %%
images[4][0]
# Out:
# <PIL.Image.Image image mode=RGB size=500x450>

# %%
print(np.array(images[4][0]).shape)
# Out:
# (450, 500, 3)

# %% [markdown]
# ## Image Transformation

# %% [markdown]
# PyTorch transformations are crucial for preparing datasets before training machine learning models. They ensure standardization and normalization, which scale data points uniformly to prevent features with large ranges from dominating the training process. Transformations also enable data augmentation through techniques like rotation, flipping, and cropping, helping prevent overfitting and improve model generalization. Additionally, transformations ensure consistency by resizing images to uniform dimensions, which is necessary for batch processing in neural networks.

# %%
import torchvision.transforms as transforms

# this is the mean and standard deviation for imagenet dataset
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])

transform = transforms.Compose([
        # transforms.ColorJitter(brightness=(0.5, 1.5)),  # Adjust brightness
        transforms.Resize((128,128)),
        # transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        # transforms.Normalize(mean, std),
        transforms.Grayscale()
    ])

# %%
images = torchvision.datasets.ImageFolder('mixture/',transform)

# %%
class_names = images.classes
print(images.classes)
print(len(images))
print(len(images[99]))

image_tensor = images[100][0]

print(image_tensor.shape)

image_label = images[100][1]

print(image_label)

print(images[0][0]*255,images[0][1])

image_to_display = image_tensor.permute(1, 2, 0).cpu().numpy()

# Display the image
plt.title('GT: '+class_names[int(image_label)])
plt.imshow(image_to_display, cmap='gray')
plt.show()
# Out:
# ['S00', 'S05', 'S10', 'S20', 'S30', 'S40']
# 183
# 2
# torch.Size([1, 128, 128])
# 2
# tensor([[[ 88.0082,  50.0120,  51.0119,  ..., 111.9871, 139.8810, 167.3468],
#          [ 46.0124,  51.0119,  53.0117,  ..., 108.8133, 138.8811, 158.3477],
#          [ 49.8980,  51.0119,  51.0119,  ..., 109.8841, 141.8808, 157.3478],
#          ...,
#          [ 21.1244,  19.5267,  13.3532,  ..., 105.7308,  58.1854,  72.0530],
#          [ 14.2391,  14.2283,  10.1686,  ...,  89.1885,  69.1134,  92.6380],
#          [ 14.8261,  11.0545,   8.6356,  ...,  89.6445,  70.7003,  88.4705]]]) 0

# %%
image_to_display.shape
# Out:
# (128, 128, 1)

# %% [markdown]
# ## Data Split for Training, Validation, and Testing

# %%
data_size = len(images.imgs)
train_size = int(data_size*0.7)
val_size = (data_size-train_size)//2
test_size = data_size-train_size-val_size
train_set, val_set, test_set = torch.utils.data.random_split(images, (train_size,val_size,test_size))
train_size,test_size,val_size
# Out:
# (128, 28, 27)

# %% [markdown]
# ## Dataloader

# %% [markdown]
# PyTorch's DataLoader is crucial for efficiently handling large datasets and optimizing the data loading process in deep learning workflows. It allows you to split your dataset into batches, providing an iterable interface to access these batches sequentially, which is essential for training neural networks.

# %%
from torch.utils.data import DataLoader

batch_size=32

train_dataloader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=1)
test_dataloader = DataLoader(test_set, batch_size=batch_size, shuffle=True, num_workers=1)
val_dataloader = DataLoader(val_set, batch_size=batch_size, shuffle=True, num_workers=1)

# %% [markdown]
# ### visualize the input examples

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    # inp = std * inp + mean # correct the nornalization
    # inp = np.clip(inp, 0, 1)
    plt.imshow(inp)

# Get a batch of training data
inputs, classes = next(iter(train_dataloader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)
plt.figure(figsize=(10,5))
imshow(out, title='Input Examples')
print([class_names[i] for i in classes])
# Out:
# ['S00', 'S20', 'S30', 'S20', 'S30', 'S10', 'S20', 'S05', 'S10', 'S20', 'S00', 'S10', 'S05', 'S10', 'S05', 'S10', 'S30', 'S10', 'S05', 'S10', 'S05', 'S05', 'S05', 'S30', 'S05', 'S30', 'S00', 'S00', 'S00', 'S30', 'S00', 'S10']

# %%
test_set[0][0].shape
# Out:
# torch.Size([1, 128, 128])

# %% [markdown]
# ### Result Visualization

# %% [markdown]
# # Simple Neural Network

# %%
import torch.nn as nn

class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.fc1 = nn.Linear(16384, 1000)
        self.fc2 = nn.Linear(1000, 100)
        self.fc3 = nn.Linear(100, 6)    # Output layer is the same dimension as the classes

    def forward(self, x):
        x = x.view(-1, 16384)  # Flatten the input
        x = torch.relu(self.fc1(x))  # Activation function for hidden layer
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

model = SimpleModel().to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.0001, momentum=0.9)

# %% [markdown]
# ## Training

# %%
since = time.time()

best_acc = 0.0
num_epochs=50

for epoch in range(num_epochs):
    print('-' * 10)

    model.train()  # Set model to training mode
    train_running_loss = 0.0
    train_running_corrects = 0

    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # backward + optimize only if in training phase
        loss.backward()
        optimizer.step()

        # statistics
        train_running_loss += loss.item() * inputs.size(0)
        train_running_corrects += torch.sum(preds == labels.data)

    train_epoch_loss = train_running_loss / len(train_set)
    train_accuracy = train_running_corrects.double() / len(train_set)
    print(f"Epoch {epoch + 1}/{num_epochs}, Training Loss: {train_epoch_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%")

    # Each epoch has a validation phase

    model.eval()   # Set model to evaluate mode
    val_running_loss = 0.0
    val_running_corrects = 0

    # Iterate over data.
    for inputs, labels in val_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # statistics
        val_running_loss += loss.item() * inputs.size(0)
        val_running_corrects += torch.sum(preds == labels.data)

    val_epoch_loss = val_running_loss / len(val_set)
    val_accuracy = val_running_corrects.double() / len(val_set)
    print(f"Epoch {epoch + 1}/{num_epochs}, Validation Loss: {val_epoch_loss:.4f}, validation Accuracy: {val_accuracy:.2f}%")

        # deep copy the model
    if  val_accuracy > best_acc:
        best_acc = val_accuracy
        best_model = model.state_dict()

time_elapsed = time.time() - since
print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
print('Best val Acc: {:4f}'.format(best_acc))
# Out:
# ----------
# Epoch 1/50, Training Loss: 1.8119, Training Accuracy: 0.04%
# Epoch 1/50, Validation Loss: 1.8244, validation Accuracy: 0.11%
# ----------
# Epoch 2/50, Training Loss: 1.8091, Training Accuracy: 0.04%
# Epoch 2/50, Validation Loss: 1.8210, validation Accuracy: 0.11%
# ----------
# Epoch 3/50, Training Loss: 1.8037, Training Accuracy: 0.08%
# Epoch 3/50, Validation Loss: 1.8166, validation Accuracy: 0.11%
# ----------
# Epoch 4/50, Training Loss: 1.7981, Training Accuracy: 0.12%
# Epoch 4/50, Validation Loss: 1.8126, validation Accuracy: 0.11%
# ----------
# Epoch 5/50, Training Loss: 1.7929, Training Accuracy: 0.12%
# Epoch 5/50, Validation Loss: 1.8086, validation Accuracy: 0.07%
# ----------
# Epoch 6/50, Training Loss: 1.7872, Training Accuracy: 0.12%
# Epoch 6/50, Validation Loss: 1.8052, validation Accuracy: 0.04%
# ----------
# Epoch 7/50, Training Loss: 1.7818, Training Accuracy: 0.16%
# Epoch 7/50, Validation Loss: 1.8020, validation Accuracy: 0.04%
# ----------
# Epoch 8/50, Training Loss: 1.7767, Training Accuracy: 0.28%
# Epoch 8/50, Validation Loss: 1.7990, validation Accuracy: 0.15%
# ----------
# Epoch 9/50, Training Loss: 1.7721, Training Accuracy: 0.42%
# Epoch 9/50, Validation Loss: 1.7957, validation Accuracy: 0.15%
# ----------
# Epoch 10/50, Training Loss: 1.7672, Training Accuracy: 0.38%
# Epoch 10/50, Validation Loss: 1.7930, validation Accuracy: 0.15%
# ----------
# Epoch 11/50, Training Loss: 1.7630, Training Accuracy: 0.34%
# Epoch 11/50, Validation Loss: 1.7905, validation Accuracy: 0.15%
# ----------
# Epoch 12/50, Training Loss: 1.7584, Training Accuracy: 0.34%
# Epoch 12/50, Validation Loss: 1.7877, validation Accuracy: 0.15%
# ----------
# Epoch 13/50, Training Loss: 1.7546, Training Accuracy: 0.34%
# Epoch 13/50, Validation Loss: 1.7847, validation Accuracy: 0.15%
# ----------
# Epoch 14/50, Training Loss: 1.7505, Training Accuracy: 0.33%
# Epoch 14/50, Validation Loss: 1.7818, validation Accuracy: 0.15%
# ----------
# Epoch 15/50, Training Loss: 1.7464, Training Accuracy: 0.33%
# Epoch 15/50, Validation Loss: 1.7788, validation Accuracy: 0.11%
# ----------
# Epoch 16/50, Training Loss: 1.7428, Training Accuracy: 0.32%
# Epoch 16/50, Validation Loss: 1.7760, validation Accuracy: 0.11%
# ----------
# Epoch 17/50, Training Loss: 1.7387, Training Accuracy: 0.32%
# Epoch 17/50, Validation Loss: 1.7733, validation Accuracy: 0.11%
# ----------
# Epoch 18/50, Training Loss: 1.7346, Training Accuracy: 0.32%
# Epoch 18/50, Validation Loss: 1.7704, validation Accuracy: 0.11%
# ----------
# Epoch 19/50, Training Loss: 1.7305, Training Accuracy: 0.32%
# Epoch 19/50, Validation Loss: 1.7675, validation Accuracy: 0.11%
# ----------
# Epoch 20/50, Training Loss: 1.7267, Training Accuracy: 0.32%
# Epoch 20/50, Validation Loss: 1.7648, validation Accuracy: 0.11%
# ----------
# Epoch 21/50, Training Loss: 1.7225, Training Accuracy: 0.32%
# Epoch 21/50, Validation Loss: 1.7624, validation Accuracy: 0.11%
# ----------
# Epoch 22/50, Training Loss: 1.7185, Training Accuracy: 0.32%
# Epoch 22/50, Validation Loss: 1.7598, validation Accuracy: 0.11%
# ----------
# Epoch 23/50, Training Loss: 1.7150, Training Accuracy: 0.32%
# Epoch 23/50, Validation Loss: 1.7575, validation Accuracy: 0.11%
# ----------
# Epoch 24/50, Training Loss: 1.7113, Training Accuracy: 0.32%
# Epoch 24/50, Validation Loss: 1.7551, validation Accuracy: 0.11%
# ----------
# Epoch 25/50, Training Loss: 1.7075, Training Accuracy: 0.32%
# Epoch 25/50, Validation Loss: 1.7529, validation Accuracy: 0.11%
# ----------
# Epoch 26/50, Training Loss: 1.7043, Training Accuracy: 0.32%
# Epoch 26/50, Validation Loss: 1.7510, validation Accuracy: 0.11%
# ----------
# Epoch 27/50, Training Loss: 1.7009, Training Accuracy: 0.32%
# Epoch 27/50, Validation Loss: 1.7488, validation Accuracy: 0.11%
# ----------
# Epoch 28/50, Training Loss: 1.6974, Training Accuracy: 0.32%
# Epoch 28/50, Validation Loss: 1.7468, validation Accuracy: 0.11%
# ----------
# Epoch 29/50, Training Loss: 1.6942, Training Accuracy: 0.32%
# Epoch 29/50, Validation Loss: 1.7449, validation Accuracy: 0.11%
# ----------
# Epoch 30/50, Training Loss: 1.6911, Training Accuracy: 0.32%
# Epoch 30/50, Validation Loss: 1.7430, validation Accuracy: 0.11%
# ----------
# Epoch 31/50, Training Loss: 1.6882, Training Accuracy: 0.32%
# Epoch 31/50, Validation Loss: 1.7412, validation Accuracy: 0.11%
# ----------
# Epoch 32/50, Training Loss: 1.6852, Training Accuracy: 0.33%
# Epoch 32/50, Validation Loss: 1.7394, validation Accuracy: 0.11%
# ----------
# Epoch 33/50, Training Loss: 1.6823, Training Accuracy: 0.34%
# Epoch 33/50, Validation Loss: 1.7373, validation Accuracy: 0.11%
# ----------
# Epoch 34/50, Training Loss: 1.6797, Training Accuracy: 0.34%
# Epoch 34/50, Validation Loss: 1.7355, validation Accuracy: 0.11%
# ----------
# Epoch 35/50, Training Loss: 1.6765, Training Accuracy: 0.34%
# Epoch 35/50, Validation Loss: 1.7339, validation Accuracy: 0.11%
# ----------
# Epoch 36/50, Training Loss: 1.6740, Training Accuracy: 0.34%
# Epoch 36/50, Validation Loss: 1.7323, validation Accuracy: 0.11%
# ----------
# Epoch 37/50, Training Loss: 1.6710, Training Accuracy: 0.34%
# Epoch 37/50, Validation Loss: 1.7305, validation Accuracy: 0.11%
# ----------
# Epoch 38/50, Training Loss: 1.6685, Training Accuracy: 0.34%
# Epoch 38/50, Validation Loss: 1.7288, validation Accuracy: 0.11%
# ----------
# Epoch 39/50, Training Loss: 1.6662, Training Accuracy: 0.34%
# Epoch 39/50, Validation Loss: 1.7272, validation Accuracy: 0.11%
# ----------
# Epoch 40/50, Training Loss: 1.6633, Training Accuracy: 0.34%
# Epoch 40/50, Validation Loss: 1.7252, validation Accuracy: 0.11%
# ----------
# Epoch 41/50, Training Loss: 1.6611, Training Accuracy: 0.35%
# Epoch 41/50, Validation Loss: 1.7238, validation Accuracy: 0.11%
# ----------
# Epoch 42/50, Training Loss: 1.6585, Training Accuracy: 0.35%
# Epoch 42/50, Validation Loss: 1.7222, validation Accuracy: 0.15%
# ----------
# Epoch 43/50, Training Loss: 1.6560, Training Accuracy: 0.34%
# Epoch 43/50, Validation Loss: 1.7208, validation Accuracy: 0.15%
# ----------
# Epoch 44/50, Training Loss: 1.6537, Training Accuracy: 0.34%
# Epoch 44/50, Validation Loss: 1.7192, validation Accuracy: 0.15%
# ----------
# Epoch 45/50, Training Loss: 1.6515, Training Accuracy: 0.35%
# Epoch 45/50, Validation Loss: 1.7179, validation Accuracy: 0.15%
# ----------
# Epoch 46/50, Training Loss: 1.6494, Training Accuracy: 0.35%
# Epoch 46/50, Validation Loss: 1.7162, validation Accuracy: 0.15%
# ----------
# Epoch 47/50, Training Loss: 1.6466, Training Accuracy: 0.39%
# Epoch 47/50, Validation Loss: 1.7149, validation Accuracy: 0.15%
# ----------
# Epoch 48/50, Training Loss: 1.6446, Training Accuracy: 0.39%
# Epoch 48/50, Validation Loss: 1.7135, validation Accuracy: 0.19%
# ----------
# Epoch 49/50, Training Loss: 1.6429, Training Accuracy: 0.41%
# Epoch 49/50, Validation Loss: 1.7124, validation Accuracy: 0.19%
# ----------
# Epoch 50/50, Training Loss: 1.6403, Training Accuracy: 0.40%
# Epoch 50/50, Validation Loss: 1.7114, validation Accuracy: 0.19%
# Training complete in 0m 41s
# Best val Acc: 0.185185

# %% [markdown]
# # Train a Model with Pretrained Weights

# %% [markdown]
# We need to modigy the original pre-defined model becuase our input channel is only one. Also the output classes of the original resnet is 1000 whereas we only want 6 classes.

# %%
model = torchvision.models.resnet18(pretrained=True)

num_ftrs = model.fc.in_features
# The last layer should have len(class_names neruons)
model.fc = nn.Linear(num_ftrs, len(class_names))

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3,bias=False)

model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# /usr/local/lib/python3.13/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 202MB/s]

# %%
since = time.time()

best_acc = 0.0
num_epochs=50

for epoch in range(num_epochs):
    print('-' * 10)

    model.train()  # Set model to training mode
    train_running_loss = 0.0
    train_running_corrects = 0

    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # backward + optimize only if in training phase
        loss.backward()
        optimizer.step()

        # statistics
        train_running_loss += loss.item() * inputs.size(0)
        train_running_corrects += torch.sum(preds == labels.data)

    train_epoch_loss = train_running_loss / len(train_set)
    train_accuracy = train_running_corrects.double() / len(train_set)
    print(f"Epoch {epoch + 1}/{num_epochs}, Training Loss: {train_epoch_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%")

    # Each epoch has a validation phase

    model.eval()   # Set model to evaluate mode
    val_running_loss = 0.0
    val_running_corrects = 0

    # Iterate over data.
    for inputs, labels in val_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # statistics
        val_running_loss += loss.item() * inputs.size(0)
        val_running_corrects += torch.sum(preds == labels.data)

    val_epoch_loss = val_running_loss / len(val_set)
    val_accuracy = val_running_corrects.double() / len(val_set)
    print(f"Epoch {epoch + 1}/{num_epochs}, Validation Loss: {val_epoch_loss:.4f}, validation Accuracy: {val_accuracy:.2f}%")

        # deep copy the model
    if  val_accuracy > best_acc:
        best_acc = val_accuracy
        best_model = model.state_dict()

time_elapsed = time.time() - since
print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
print('Best val Acc: {:4f}'.format(best_acc))
# Out:
# ----------
# Epoch 1/50, Training Loss: 1.6484, Training Accuracy: 0.33%
# Epoch 1/50, Validation Loss: 1.8255, validation Accuracy: 0.33%
# ----------
# Epoch 2/50, Training Loss: 0.5044, Training Accuracy: 0.94%
# Epoch 2/50, Validation Loss: 1.7381, validation Accuracy: 0.33%
# ----------
# Epoch 3/50, Training Loss: 0.1953, Training Accuracy: 0.98%
# Epoch 3/50, Validation Loss: 1.6350, validation Accuracy: 0.33%
# ----------
# Epoch 4/50, Training Loss: 0.0838, Training Accuracy: 1.00%
# Epoch 4/50, Validation Loss: 1.5764, validation Accuracy: 0.48%
# ----------
# Epoch 5/50, Training Loss: 0.0471, Training Accuracy: 1.00%
# Epoch 5/50, Validation Loss: 1.5167, validation Accuracy: 0.37%
# ----------
# Epoch 6/50, Training Loss: 0.0284, Training Accuracy: 1.00%
# Epoch 6/50, Validation Loss: 1.4554, validation Accuracy: 0.44%
# ----------
# Epoch 7/50, Training Loss: 0.0231, Training Accuracy: 1.00%
# Epoch 7/50, Validation Loss: 1.4437, validation Accuracy: 0.41%
# ----------
# Epoch 8/50, Training Loss: 0.0133, Training Accuracy: 1.00%
# Epoch 8/50, Validation Loss: 1.4088, validation Accuracy: 0.41%
# ----------
# Epoch 9/50, Training Loss: 0.0133, Training Accuracy: 1.00%
# Epoch 9/50, Validation Loss: 1.3339, validation Accuracy: 0.41%
# ----------
# Epoch 10/50, Training Loss: 0.0069, Training Accuracy: 1.00%
# Epoch 10/50, Validation Loss: 1.2540, validation Accuracy: 0.44%
# ----------
# Epoch 11/50, Training Loss: 0.0095, Training Accuracy: 1.00%
# Epoch 11/50, Validation Loss: 1.1406, validation Accuracy: 0.56%
# ----------
# Epoch 12/50, Training Loss: 0.0071, Training Accuracy: 1.00%
# Epoch 12/50, Validation Loss: 0.9895, validation Accuracy: 0.59%
# ----------
# Epoch 13/50, Training Loss: 0.0060, Training Accuracy: 1.00%
# Epoch 13/50, Validation Loss: 0.8184, validation Accuracy: 0.70%
# ----------
# Epoch 14/50, Training Loss: 0.0054, Training Accuracy: 1.00%
# Epoch 14/50, Validation Loss: 0.6393, validation Accuracy: 0.78%
# ----------
# Epoch 15/50, Training Loss: 0.0046, Training Accuracy: 1.00%
# Epoch 15/50, Validation Loss: 0.5063, validation Accuracy: 0.81%
# ----------
# Epoch 16/50, Training Loss: 0.0062, Training Accuracy: 1.00%
# Epoch 16/50, Validation Loss: 0.4345, validation Accuracy: 0.85%
# ----------
# Epoch 17/50, Training Loss: 0.0035, Training Accuracy: 1.00%
# Epoch 17/50, Validation Loss: 0.3891, validation Accuracy: 0.85%
# ----------
# Epoch 18/50, Training Loss: 0.0040, Training Accuracy: 1.00%
# Epoch 18/50, Validation Loss: 0.3747, validation Accuracy: 0.81%
# ----------
# Epoch 19/50, Training Loss: 0.0039, Training Accuracy: 1.00%
# Epoch 19/50, Validation Loss: 0.3688, validation Accuracy: 0.85%
# ----------
# Epoch 20/50, Training Loss: 0.0032, Training Accuracy: 1.00%
# Epoch 20/50, Validation Loss: 0.3744, validation Accuracy: 0.85%
# ----------
# Epoch 21/50, Training Loss: 0.0028, Training Accuracy: 1.00%
# Epoch 21/50, Validation Loss: 0.3927, validation Accuracy: 0.85%
# ----------
# Epoch 22/50, Training Loss: 0.0034, Training Accuracy: 1.00%
# Epoch 22/50, Validation Loss: 0.4072, validation Accuracy: 0.85%
# ----------
# Epoch 23/50, Training Loss: 0.0037, Training Accuracy: 1.00%
# Epoch 23/50, Validation Loss: 0.4177, validation Accuracy: 0.85%
# ----------
# Epoch 24/50, Training Loss: 0.0044, Training Accuracy: 1.00%
# Epoch 24/50, Validation Loss: 0.4216, validation Accuracy: 0.85%
# ----------
# Epoch 25/50, Training Loss: 0.0053, Training Accuracy: 1.00%
# Epoch 25/50, Validation Loss: 0.4262, validation Accuracy: 0.85%
# ----------
# Epoch 26/50, Training Loss: 0.0022, Training Accuracy: 1.00%
# Epoch 26/50, Validation Loss: 0.4251, validation Accuracy: 0.85%
# ----------
# Epoch 27/50, Training Loss: 0.0022, Training Accuracy: 1.00%
# Epoch 27/50, Validation Loss: 0.4229, validation Accuracy: 0.85%
# ----------
# Epoch 28/50, Training Loss: 0.0025, Training Accuracy: 1.00%
# Epoch 28/50, Validation Loss: 0.4228, validation Accuracy: 0.85%
# ----------
# Epoch 29/50, Training Loss: 0.0034, Training Accuracy: 1.00%
# Epoch 29/50, Validation Loss: 0.4198, validation Accuracy: 0.85%
# ----------
# Epoch 30/50, Training Loss: 0.0021, Training Accuracy: 1.00%
# Epoch 30/50, Validation Loss: 0.4178, validation Accuracy: 0.85%
# ----------
# Epoch 31/50, Training Loss: 0.0026, Training Accuracy: 1.00%
# Epoch 31/50, Validation Loss: 0.4166, validation Accuracy: 0.85%
# ----------
# Epoch 32/50, Training Loss: 0.0022, Training Accuracy: 1.00%
# Epoch 32/50, Validation Loss: 0.4158, validation Accuracy: 0.85%
# ----------
# Epoch 33/50, Training Loss: 0.0019, Training Accuracy: 1.00%
# Epoch 33/50, Validation Loss: 0.4163, validation Accuracy: 0.85%
# ----------
# Epoch 34/50, Training Loss: 0.0018, Training Accuracy: 1.00%
# Epoch 34/50, Validation Loss: 0.4135, validation Accuracy: 0.85%
# ----------
# Epoch 35/50, Training Loss: 0.0015, Training Accuracy: 1.00%
# Epoch 35/50, Validation Loss: 0.4152, validation Accuracy: 0.85%
# ----------
# Epoch 36/50, Training Loss: 0.0026, Training Accuracy: 1.00%
# Epoch 36/50, Validation Loss: 0.4183, validation Accuracy: 0.85%
# ----------
# Epoch 37/50, Training Loss: 0.0016, Training Accuracy: 1.00%
# Epoch 37/50, Validation Loss: 0.4327, validation Accuracy: 0.85%
# ----------
# Epoch 38/50, Training Loss: 0.0019, Training Accuracy: 1.00%
# Epoch 38/50, Validation Loss: 0.4401, validation Accuracy: 0.85%
# ----------
# Epoch 39/50, Training Loss: 0.0014, Training Accuracy: 1.00%
# Epoch 39/50, Validation Loss: 0.4452, validation Accuracy: 0.85%
# ----------
# Epoch 40/50, Training Loss: 0.0017, Training Accuracy: 1.00%
# Epoch 40/50, Validation Loss: 0.4501, validation Accuracy: 0.85%
# ----------
# Epoch 41/50, Training Loss: 0.0035, Training Accuracy: 1.00%
# Epoch 41/50, Validation Loss: 0.4479, validation Accuracy: 0.85%
# ----------
# Epoch 42/50, Training Loss: 0.0014, Training Accuracy: 1.00%
# Epoch 42/50, Validation Loss: 0.4446, validation Accuracy: 0.85%
# ----------
# Epoch 43/50, Training Loss: 0.0014, Training Accuracy: 1.00%
# Epoch 43/50, Validation Loss: 0.4418, validation Accuracy: 0.85%
# ----------
# Epoch 44/50, Training Loss: 0.0014, Training Accuracy: 1.00%
# Epoch 44/50, Validation Loss: 0.4418, validation Accuracy: 0.85%
# ----------
# Epoch 45/50, Training Loss: 0.0013, Training Accuracy: 1.00%
# Epoch 45/50, Validation Loss: 0.4425, validation Accuracy: 0.85%
# ----------
# Epoch 46/50, Training Loss: 0.0011, Training Accuracy: 1.00%
# Epoch 46/50, Validation Loss: 0.4415, validation Accuracy: 0.85%
# ----------
# Epoch 47/50, Training Loss: 0.0022, Training Accuracy: 1.00%
# Epoch 47/50, Validation Loss: 0.4364, validation Accuracy: 0.85%
# ----------
# Epoch 48/50, Training Loss: 0.0013, Training Accuracy: 1.00%
# Epoch 48/50, Validation Loss: 0.4369, validation Accuracy: 0.85%
# ----------
# Epoch 49/50, Training Loss: 0.0010, Training Accuracy: 1.00%
# Epoch 49/50, Validation Loss: 0.4367, validation Accuracy: 0.85%
# ----------
# Epoch 50/50, Training Loss: 0.0014, Training Accuracy: 1.00%
# Epoch 50/50, Validation Loss: 0.4359, validation Accuracy: 0.85%
# Training complete in 0m 49s
# Best val Acc: 0.851852

# %% [markdown]
# ### Saving the Best Model and Load

# %%
torch.save(best_model, 'best_model.pth')

# %% [markdown]
# This is testing on the testing portion, which is from the same mixture.

# %%
model = torchvision.models.resnet18(pretrained=True)

num_ftrs = model.fc.in_features
# The last layer should have len(class_names neruons)
model.fc = nn.Linear(num_ftrs, len(class_names))

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3,bias=False)

model.load_state_dict(torch.load('best_model.pth'))

model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=6, bias=True)
# )

# %%
model.eval()
too_many_figures=0

sm = torch.nn.Softmax()
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_dataloader):
        inputs = inputs.to(device)
        l=labels
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        confidence = np.amax(np.array(sm(outputs.cpu())),1)

        for j in range(inputs.size()[0]):
            fig = plt.figure()
            ax = plt.subplot()
            ax.set_xlabel('Groun Truth: {}'.format(class_names[l[j]]))
            ax.set_ylabel('Prediction: {}'.format(class_names[preds[j]]))
            ax.set_title('Confidence {:.2f}'.format(confidence[j]))

            inp = inputs.cpu().data[j].numpy().transpose((1, 2, 0))

            # inp = std * inp + mean
            # inp = np.clip(inp, 0, 1)
            ax.imshow(inp, cmap='gray')
            too_many_figures+=1
            if too_many_figures>10:
                break
        if too_many_figures>10:
            break
# Out:
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py:1779: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# /tmp/ipykernel_1773/474806721.py:13: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   confidence = np.amax(np.array(sm(outputs.cpu())),1)

# %% [markdown]
# # Test on unseen data

# %% [markdown]
# Now we make the test dataloader to load the random selected pictures and get the confusion matrix. We can see the model works for the random selected pictures. The key for next steps is to get diverse training dataset to cover many different conditions. This also can be done by data augmentation.

# %%
if "RANDOM_PICTURES_TO_VERIFY.zip" not in os.listdir():

    gdown.download('https://drive.google.com/uc?export=download&id=1zMIA-i0_M6mVPCnMshJQxgVXz8u_m40r')
    ! unzip -q 'RANDOM_PICTURES_TO_VERIFY.zip'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1zMIA-i0_M6mVPCnMshJQxgVXz8u_m40r
# From (redirected): https://drive.google.com/uc?export=download&id=1zMIA-i0_M6mVPCnMshJQxgVXz8u_m40r&confirm=t&uuid=e645055d-f3fe-493b-a205-b0e38c8a60b0
# To: /content/RANDOM_PICTURES_TO_VERIFY.zip
# 100%|██████████| 569M/569M [00:11<00:00, 48.7MB/s]

# %%
test_set = torchvision.datasets.ImageFolder('RANDOM_PICTURES_TO_VERIFY/',transform)

# %%
test_dataloader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=1)

# %% [markdown]
# # Confusion Matrix Result Analysis

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
model.to(device)
with torch.no_grad():

    for i, (inputs, classes) in enumerate(test_dataloader):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1

print(confusion_matrix)
# Out:
# tensor([[ 906.,    0.,    0.,    0.,    0.,    0.],
#         [   0., 3189.,    0.,    0.,    0.,    0.],
#         [   0.,  406.,  890.,   20.,   18.,    4.],
#         [   0.,   15.,    0.,  607.,   60.,    0.],
#         [  13.,    0.,    0.,    0., 1210.,   30.],
#         [   0.,    0.,    0.,    0.,   82.,  455.]])

# %%
df_cm = pd.DataFrame(confusion_matrix.numpy().astype('int'), index = [i for i in class_names],
                  columns = [i for i in class_names])

test_acc=np.trace(confusion_matrix.numpy().astype('int'))/np.sum(np.sum(df_cm))

plt.figure(figsize = (len(class_names),len(class_names)))
plt.title('Confusing Matrix with Testing Accuracy: {:0.2f}%'.format(test_acc*100))

sn.heatmap(df_cm, annot=True,fmt='g',cmap="YlGnBu")
plt.xlabel('Predicted Label')
plt.ylabel('Ground Truth')
plt.savefig('Confusing Matrix.pdf',dpi=300)
# Out:
# /usr/local/lib/python3.13/dist-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
cm=confusion_matrix.numpy().astype('int')
recall = np.diag(cm) /( np.sum(cm, axis = 1)+0.000000001)
precision = np.diag(cm) /( np.sum(cm, axis = 0)+0.000000001)
f1_per_class = 2 * (precision * recall) / (precision + recall)

data = {'Class': images.classes, 'Precision': precision, 'Recall': recall, 'F1': f1_per_class}
df = pd.DataFrame(data)

styled_df = df.style.format({'Precision': '{:.2%}', 'Recall': '{:.2%}','F1': '{:.2%}'})

print(styled_df)

# Save the DataFrame to a CSV file
df.to_csv('precision_recall_table.csv', index=False)
# Out:
# <pandas.io.formats.style.Styler object at 0x7fbf60ad6e40>

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Assuming `classes` contains the true labels and `preds` contains the predicted labels from the test set
# We need to collect all true labels and predictions from the test_dataloader

all_labels = []
all_preds = []

with torch.no_grad():
    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())

# Calculate macro-averaged metrics
macro_precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
macro_recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)
macro_f1 = f1_score(all_labels, all_preds, average='macro', zero_division=0)

# Calculate weighted-averaged metrics
weighted_precision = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
weighted_recall = recall_score(all_labels, all_preds, average='weighted', zero_division=0)
weighted_f1 = f1_score(all_labels, all_preds, average='weighted', zero_division=0)

print(f"Macro-averaged Precision: {macro_precision:.2f}")
print(f"Macro-averaged Recall: {macro_recall:.2f}")
print(f"Macro-averaged F1-score: {macro_f1:.2f}")
print(f"Weighted-averaged Precision: {weighted_precision:.2f}")
print(f"Weighted-averaged Recall: {weighted_recall:.2f}")
print(f"Weighted-averaged F1-score: {weighted_f1:.2f}")
# Out:
# Macro-averaged Precision: 0.94
# Macro-averaged Recall: 0.89
# Macro-averaged F1-score: 0.91
# Weighted-averaged Precision: 0.93
# Weighted-averaged Recall: 0.92
# Weighted-averaged F1-score: 0.91

# %% [markdown]
# ### Macro and Weighted Averaged Metrics
#
# Here are the macro-averaged and weighted-averaged metrics for the model's performance on the test set:
#
# | Metric              | Value      |
# | :------------------ | :--------- |
# | **Macro Precision** | `{:.2%}`.format(macro_precision)|
# | **Macro Recall**    | `{:.2%}`.format(macro_recall) |
# | **Macro F1-score**  | `{:.2%}`.format(macro_f1)     |
# | **Weighted Precision**| `{:.2%}`.format(weighted_precision)|
# | **Weighted Recall** | `{:.2%}`.format(weighted_recall)|
# | **Weighted F1-score** | `{:.2%}`.format(weighted_f1)    |

# %%
df
# Out:
#   Class  Precision    Recall        F1
# 0   S00   0.985854  1.000000  0.992877
# 1   S05   0.883380  1.000000  0.938079
# 2   S10   1.000000  0.665172  0.798923
# 3   S20   0.968102  0.890029  0.927426
# 4   S30   0.883212  0.965682  0.922608
# 5   S40   0.930470  0.847300  0.886940

# %%
styled_df = df.style.format({'Precision': '{:.2%}', 'Recall': '{:.2%}','F1': '{:.2%}'})
styled_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_4bc60" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bc60_level0_col0" class="col_heading level0 col0" >Class</th>
#       <th id="T_4bc60_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_4bc60_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4bc60_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bc60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bc60_row0_col0" class="data row0 col0" >S00</td>
#       <td id="T_4bc60_row0_col1" class="data row0 col1" >98.59%</td>
#       <td id="T_4bc60_row0_col2" class="data row0 col2" >100.00%</td>
#       <td id="T_4bc60_row0_col3" class="data row0 col3" >99.29%</td>
#     </tr>
#     <tr>
#       <th id="T_4bc60_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4bc60_row1_col0" class="data row1 col0" >S05</td>
#       <td id="T_4bc60_row1_col1" class="data row1 col1" >88.34%</td>
#       <td id="T_4bc60_row1_col2" class="data row1 col2" >100.00%</td>
#       <td id="T_4bc60_row1_col3" class="data row1 col3" >93.81%</td>
#     </tr>
#     <tr>
#       <th id="T_4bc60_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4bc60_row2_col0" class="data row2 col0" >S10</td>
#       <td id="T_4bc60_row2_col1" class="data row2 col1" >100.00%</td>
#       <td id="T_4bc60_row2_col2" class="data row2 col2" >66.52%</td>
#       <td id="T_4bc60_row2_col3" class="data row2 col3" >79.89%</td>
#     </tr>
#     <tr>
#       <th id="T_4bc60_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4bc60_row3_col0" class="data row3 col0" >S20</td>
#       <td id="T_4bc60_row3_col1" class="data row3 col1" >96.81%</td>
#       <td id="T_4bc60_row3_col2" class="data row3 col2" >89.00%</td>
#       <td id="T_4bc60_row3_col3" class="data row3 col3" >92.74%</td>
#     </tr>
#     <tr>
#       <th id="T_4bc60_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4bc60_row4_col0" class="data row4 col0" >S30</td>
#       <td id="T_4bc60_row4_col1" class="data row4 col1" >88.32%</td>
#       <td id="T_4bc60_row4_col2" class="data row4 col2" >96.57%</td>
#       <td id="T_4bc60_row4_col3" class="data row4 col3" >92.26%</td>
#     </tr>
#     <tr>
#       <th id="T_4bc60_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4bc60_row5_col0" class="data row5 col0" >S40</td>
#       <td id="T_4bc60_row5_col1" class="data row5 col1" >93.05%</td>
#       <td id="T_4bc60_row5_col2" class="data row5 col2" >84.73%</td>
#       <td id="T_4bc60_row5_col3" class="data row5 col3" >88.69%</td>
#     </tr>
#   </tbody>
# </table>

# %%
inputs, classes = next(iter(test_dataloader))

image = inputs[0].to(device).unsqueeze(0)

outputs = model(image)

print('Ground truth label is a {}'.format(class_names[classes[0]]))

print(outputs)

_, preds = torch.max(outputs, 1)
print('Prediction is a {}'.format(class_names[preds]))

sm = torch.nn.Softmax()
confidences = np.array(sm(outputs.cpu().detach()))
print(confidences)

df = pd.DataFrame({'Confidences':confidences[0]},index=class_names)
df.plot.bar()
plt.title('Confidence for each class')
# Out:
# Ground truth label is a S00
# tensor([[ 7.0942, -0.7282, -1.9697, -2.6623, -1.6111, -0.7244]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Prediction is a S00
# [[9.9885905e-01 4.0018995e-04 1.1563089e-04 5.7847850e-05 1.6551517e-04
#   4.0170702e-04]]
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py:1779: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# /tmp/ipykernel_1773/348780571.py:15: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   confidences = np.array(sm(outputs.cpu().detach()))
# Text(0.5, 1.0, 'Confidence for each class')
